# %%
import gymnasium as gym
import ale_py
from gymnasium.utils.play import play

gym.register_envs(ale_py)

env = gym.make("ALE/Tetris-v5", render_mode="rgb_array")

play(env, keys_to_action=None)
#edit to test
# Out:
# A.L.E: Arcade Learning Environment (version 0.10.2+unknown)
# [Powered by Stella]
# Game console created:
#   ROM file:  /Users/ciarancope/miniconda3/envs/sklearn-env/lib/python3.13/site-packages/ale_py/roms/tetris.bin
#   Cart Name: Tetris 2600 (Colin Hughes)
#   Cart MD5:  b0e1ee07fbc73493eac5651a52f90f00
#   Display Format:  AUTO-DETECT ==> NTSC
#   ROM Size:        2048
#   Bankswitch Type: AUTO-DETECT ==> 2K
#
# Running ROM file...
# Random seed is -1350792366
# Sending Reset...
# Sending Reset...
# Sending Reset...
# Sending Reset...
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 8
#       4 from gymnasium.utils.play import play
#       6 gym.register_envs(ale_py)
# ----> 8 play(gym.make("ALE/Tetris-v5", render_mode="rgb_array"))
#
# ...
